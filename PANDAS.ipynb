# %%
PANDAS

# %%
import pandas as pd

# %%
pd.DataFrame({'Bob':['I like it.','It was awful.'],'Sure' : ['pretty good.','Bland.']})
# Out:
#              Bob          Sure
# 0     I like it.  pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob':['I like it.','It was awful.'],
              'Sure' : ['pretty good.','Bland.']} ,
             index=['Product A','product B'])
# Out:
#                      Bob          Sure
# Product A     I like it.  pretty good.
# product B  It was awful.        Bland.

# %%
my_list=[10,20,30,40,50]
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series([30,35,40],index=['2015 Sales','2016 Sales','2017 Sales'],name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
df= pd.read_excel("Downloads/Iris.xlsx")

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df= pd.read_excel("Downloads/Iris.xlsx",index_col=0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
pd.DataFrame({'Bob':['I like it.','It was awful.'],
              'Sure' : ['pretty good.','Bland.']} ,
             index=['Product A','product B'])

# %%
pd.DataFrame({'Apples':['30'],'Bananas':['21']})
# Out:
#   Apples Bananas
# 0     30      21

# %%
pd.DataFrame({'Apples':['35','41'],'Bananas':['21','34']},index=['2017 Sales','2018 Sales'])
# Out:
#            Apples Bananas
# 2017 Sales     35      21
# 2018 Sales     41      34

# %%
 pd.Series(['4 cups','1 cups', '2 large','1 can'],index=['Flour','Milk','Eggs','Spam'],name='Dinner')
# Out:
# Flour     4 cups
# Milk      1 cups
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
df = pd.read_csv("Desktop/crop_yield.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("Desktop/crop_yield.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
pd.read_csv("D:/Sies Files/sem2/Machine Learning/Practicals/Dataset/crop_yield.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.read_csv("D:/Sies Files/sem2/Machine Learning/Practicals/Dataset/crop_yield.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df= pd.read_excel("Downloads/Iris.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df= pd.read_excel("Downloads/Iris.xlsx")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.SepalLengthCm #1
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df['SepalLengthCm'] #when column name has space and more words then square bracket  #2

# %%
df['SepalLengthCm'][145]
# Out:
# 6.7

# %%
df.iloc[0] #iloc & loc== row first
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df.iloc[:,0] #before colon indicates row; after coma that means column....iloc means index location
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df.iloc[:0]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df.iloc[:5,0:2] #
# Out:
#    Id  SepalLengthCm
# 0   1            5.1
# 1   2            4.9
# 2   3            4.7
# 3   4            4.6
# 4   5            5.0

# %%
df.iloc[:5,:2]
# Out:
#    Id  SepalLengthCm
# 0   1            5.1
# 1   2            4.9
# 2   3            4.7
# 3   4            4.6
# 4   5            5.0

# %%
df.iloc[:,0]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df.iloc[:3,5]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# Name: Species, dtype: object

# %%
df.iloc[1:3,5]
# Out:
# 1    Iris-setosa
# 2    Iris-setosa
# Name: Species, dtype: object

# %%
df.iloc[[0,1,2,3],5] #list kore dite parbo majhe jodi majh theke data dekhte chai
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# Name: Species, dtype: object

# %%
df.iloc[-5:] #tail die last 5 ta dekhte partm ,(-5) die oirokom last 5 ta row dekhte prbo
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#loc ==label based selection

# %%
df.loc[0,'Species']
# Out:
# 'Iris-setosa'

# %%
df.loc[:,['Id','PetalLengthCm','Species']]
# Out:
#       Id  PetalLengthCm         Species
# 0      1            1.4     Iris-setosa
# 1      2            1.4     Iris-setosa
# 2      3            1.3     Iris-setosa
# 3      4            1.5     Iris-setosa
# 4      5            1.4     Iris-setosa
# ..   ...            ...             ...
# 145  146            5.2  Iris-virginica
# 146  147            5.0  Iris-virginica
# 147  148            5.2  Iris-virginica
# 148  149            5.4  Iris-virginica
# 149  150            5.1  Iris-virginica
#
# [150 rows x 3 columns]

# %%
df.loc[:,['Id','PetalLengthCm','Species']]
# Out:
#       Id  PetalLengthCm         Species
# 2      3            1.3     Iris-setosa
# 3      4            1.5     Iris-setosa
# 4      5            1.4     Iris-setosa
# 5      6            1.7     Iris-setosa
# 6      7            1.4     Iris-setosa
# ..   ...            ...             ...
# 145  146            5.2  Iris-virginica
# 146  147            5.0  Iris-virginica
# 147  148            5.2  Iris-virginica
# 148  149            5.4  Iris-virginica
# 149  150            5.1  Iris-virginica
#
# [148 rows x 3 columns]

# %%
# 'iloc' e ending point exclusive and 'loc' e ending point inclusive

# %%
#MANIPULATING INDEX

# %%
df.set_index('Id')
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# CONDTIONAL SELECTION

# %%
df.PetalLengthCm >=2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: PetalLengthCm, Length: 150, dtype: bool

# %%
df.loc[df.PetalLengthCm >=2.0]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
df.loc[df.PetalWidthCm>=2.0]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# ...

# %%
df.loc[(df.PetalLengthCm >=2.0) & (df.PetalWidthCm >=2.0)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# ...

# %%
df.loc[(df.PetalLengthCm >=2.0) & (df.PetalWidthCm >=6.0)]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df.loc[(df.PetalLengthCm >=2.0) | (df.PetalWidthCm >=2.0)] # "|" means or
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# ...

# %%
df.Species.unique() #to find out unique value
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.loc[df.Species.isin(['Iris-setosa','Iris-virginica'])]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#dataset e info missing thakle.....df.null()...dile true/false dekhabe...df.isnull().sum() dile data number die bujhabe kon data missing ase ki na

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.notnull()
# Out:
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    True           True          True           True          True     True
# 1    True           True          True           True          True     True
# 2    True           True          True           True          True     True
# 3    True           True          True           True          True     True
# 4    True           True          True           True          True     True
# ..    ...            ...           ...            ...           ...      ...
# 145  True           True          True           True          True     True
# 146  True           True          True           True          True     True
# 147  True           True          True           True          True     True
# 148  True           True          True           True          True     True
# 149  True           True          True           True          True     True
#
# [150 rows x 6 columns]

# %%
df.null().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17200\2959149411.py in ?()
# ----> 1 df.null().sum()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#ASSIGNING DATA

# %%
df['Species']='BSMRAU'
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0   1            5.1           3.5            1.4           0.2  BSMRAU
# 1   2            4.9           3.0            1.4           0.2  BSMRAU
# 2   3            4.7           3.2            1.3           0.2  BSMRAU
# 3   4            4.6           3.1            1.5           0.2  BSMRAU
# 4   5            5.0           3.6            1.4           0.2  BSMRAU

# %%
df['Species']= range(0,len(df),1)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        2
# 3      4            4.6           3.1            1.5           0.2        3
# 4      5            5.0           3.6            1.4           0.2        4
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3      145
# 146  147            6.3           2.5            5.0           1.9      146
# 147  148            6.5           3.0            5.2           2.0      147
# 148  149            6.2           3.4            5.4           2.3      148
# 149  150            5.9           3.0            5.1           1.8      149
#
# [150 rows x 6 columns]

# %%
df["class"]=  range(0,len(df),1)
df                                 #new column add krte chaile df("new col name")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        2
# 3      4            4.6           3.1            1.5           0.2        3
# 4      5            5.0           3.6            1.4           0.2        4
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3      145
# 146  147            6.3           2.5            5.0           1.9      146
# 147  148            6.5           3.0            5.2           2.0      147
# 148  149            6.2           3.4            5.4           2.3      148
# 149  150            5.9           3.0            5.1           1.8      149
#
#      class
# 0        0
# 1        1
# 2        2
# ...

# %%
spc=df.Species
spc
# Out:
# 0      spc
# 1      spc
# 2      spc
# 3      spc
# 4      spc
#       ...
# 145    spc
# 146    spc
# 147    spc
# 148    spc
# 149    spc
# Name: Species, Length: 150, dtype: object

# %%
import pandas as pd

# %%
df= pd.read_excel("Downloads/Iris.xlsx")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
spl_length = df.SepalLengthCm[0]
spl_length
# Out:
# 5.1

# %%
first_row= df.iloc[0,:]
first_row
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
first_description = df.iloc[:11,5]
first_description
# Out:
# 0     Iris-setosa
# 1     Iris-setosa
# 2     Iris-setosa
# 3     Iris-setosa
# 4     Iris-setosa
# 5     Iris-setosa
# 6     Iris-setosa
# 7     Iris-setosa
# 8     Iris-setosa
# 9     Iris-setosa
# 10    Iris-setosa
# Name: Species, dtype: object

# %%
sample= df.iloc[[1,2,3,5,8],:]
sample
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa

# %%
sample_df = df.loc[[0,1,10,100], ['Id','Species']]
sample_df
# Out:
#       Id         Species
# 0      1     Iris-setosa
# 1      2     Iris-setosa
# 10    11     Iris-setosa
# 100  101  Iris-virginica

# %%
setosa= df.loc[df.Species=='Iris-setosa']
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.loc[(df.SepalLengthCm >=5.0) | (df.PetalLengthCm >=2.0)]
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
big_setosa=df.loc[(df.Species =='Iris-setosa') & ((df.SepalLengthCm >=5.0) | (df.PetalLengthCm >=2.0))]
big_setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# ...

# %%
#30/12/2024

# %%
import pandas as pd

# %%
df= pd.read_csv("Downloads/crop_yield.csv/crop_yield.csv")
df.head()
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton   897.077239            27.676966
# 1  South      Clay     Rice   992.673282            18.026142
# 2  North      Loam   Barley   147.998025            29.794042
# 3  North     Sandy  Soybean   986.866331            16.644190
# 4  South      Silt    Wheat   730.379174            31.620687
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
#
#    Yield_tons_per_hectare
# 0                6.555816
# 1                8.527341
# 2                1.127443
# 3                6.517573
# 4                7.248251

# %%
df.describe() #numeric column gulo dekhabe
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
df.Yield_tons_per_hectare.describe()
# Out:
# count    1000000.000000
# mean           4.649472
# std            1.696572
# min           -1.147613
# 25%            3.417637
# 50%            4.651808
# 75%            5.879200
# max            9.963372
# Name: Yield_tons_per_hectare, dtype: float64

# %%
df.Region.describe() #non-numeric column dekhte hoile specific vabe bole dite hobe
# Out:
# count     1000000
# unique          4
# top         North
# freq       250173
# Name: Region, dtype: object

# %%
df.Rainfall_mm.mean()
# Out:
# 549.981900729363

# %%
df.Rainfall_mm.unique()
# Out:
# array([897.07723911, 992.67328162, 147.99802529, ..., 867.36204622,
#        492.81285654, 180.93618014])

# %%
df.Region.value_counts() #value_count dile specific column er unique value dibe
# Out:
# Region
# North    250173
# West     250074
# South    250054
# East     249699
# Name: count, dtype: int64

# %%
df.Temperature_Celsius.median()
# Out:
# 27.50736543143337

# %%
df.	Weather_Condition.unique()
# Out:
# array(['Cloudy', 'Rainy', 'Sunny'], dtype=object)

# %%
df.	Weather_Condition.value_counts()
# Out:
# Weather_Condition
# Sunny     333790
# Rainy     333561
# Cloudy    332649
# Name: count, dtype: int64

# %%
df.Yield_tons_per_hectare.mean()
# Out:
# 4.649472487663021

# %%
centered_yield = df.Yield_tons_per_hectare - df.Yield_tons_per_hectare.mean()
centered_yield                                                                #centered trasforming/ normalization kora jeno ager mot value same thake
# Out:
# 0         1.906344
# 1         3.877868
# 2        -3.522029
# 3         1.868100
# 4         2.598779
#             ...
# 999995   -3.301887
# 999996    2.662122
# 999997    1.113709
# 999998   -2.579314
# 999999   -1.712229
# Name: Yield_tons_per_hectare, Length: 1000000, dtype: float64

# %%
df= pd.read_excel("Downloads/winemag-data-130k-v2.xlsx")
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
print(df.points.dtype)
# Out:
# int64

# %%
df.points = df.points.astype('float64')

# %%
print(df.points.dtype)
# Out:
# float64

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.rename(columns={'points':'score'}) #rename e dictionary type pathate hobe...ei jonno columns dite hobe
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename(index={0:'firstEntry',1:'secondEntry'}) #row er name change krte "index" likhe change krte parbo
# Out:
#              Unnamed: 0   country  \
# firstEntry            0     Italy
# secondEntry           1  Portugal
# 2                     2        US
# 3                     3        US
# 4                     4        US
# ...                 ...       ...
# 129966           129966   Germany
# 129967           129967        US
# 129968           129968    France
# 129969           129969    France
# 129970           129970    France
#
#                                                    description  \
# firstEntry   Aromas include tropical fruit, broom, brimston...
# secondEntry  This is ripe and fruity, a wine that is smooth...
# 2            Tart and snappy, the flavors of lime flesh and...
# 3            Pineapple rind, lemon pith and orange blossom ...
# 4            Much like the regular bottling from 2012, this...
# ...                                                        ...
# 129966       Notes of honeysuckle and cantaloupe sweeten th...
# ...

# %%
df.rename(columns={'points':'score'},index={0:'firstEntry',1:'secondEntry'})
# Out:
#              Unnamed: 0   country  \
# firstEntry            0     Italy
# secondEntry           1  Portugal
# 2                     2        US
# 3                     3        US
# 4                     4        US
# ...                 ...       ...
# 129966           129966   Germany
# 129967           129967        US
# 129968           129968    France
# 129969           129969    France
# 129970           129970    France
#
#                                                    description  \
# firstEntry   Aromas include tropical fruit, broom, brimston...
# secondEntry  This is ripe and fruity, a wine that is smooth...
# 2            Tart and snappy, the flavors of lime flesh and...
# 3            Pineapple rind, lemon pith and orange blossom ...
# 4            Much like the regular bottling from 2012, this...
# ...                                                        ...
# 129966       Notes of honeysuckle and cantaloupe sweeten th...
# ...

# %%
df.rename_axis("wines",axis='rows').rename_axis("fields",axis='columns')
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename(columns = {'region_1':'region','region_2':'locale'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename(index={0:'wines'})
# Out:
#         Unnamed: 0   country  \
# wines            0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# wines   Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename_axis("wines",axis='rows')
# Out:
#         Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename_axis("wines",axis='columns')
# Out:
# wines   Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# wines                                         description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
df.rename_axis("wines")
# Out:
#         Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...
